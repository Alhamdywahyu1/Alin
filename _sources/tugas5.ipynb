# %% [markdown]
# # eigenvalue dan eigenvektor
#
# eigenvektor simbolnya X
# eigenvalue simbolnya y terbalik

# %%
import numpy as np
A = [[1,4],[2,3]]
evalue,evector = np.linalg.eig(A)
print(evalue)
print(np.round(evector))
# Out:
# [-1.  5.]
# [[-1. -1.]
#  [ 0. -1.]]
